# %% [markdown]
# # Classification with Amazon SageMaker XGBoost algorithm
# _**Managed training for building a classification model with Amazon SageMaker XGBoost*_

# %% [markdown]
# ## Introduction
#
# This notebook demonstrates the use of Amazon SageMaker XGBoost to train and host a classification model. [XGBoost (eXtreme Gradient Boosting)](https://xgboost.readthedocs.io) is a popular and efficient machine learning algorithm used for regression and classification tasks on tabular datasets. It implements a technique know as gradient boosting on trees, and performs remarkably well in machine learning competitions, and gets a lot of attention from customers.
#
# We use the [MNIST data](https://www.csie.ntu.edu.tw/~cjlin/libsvmtools/datasets/multiclass.html) stored in [LIBSVM](https://www.csie.ntu.edu.tw/~cjlin/libsvm/) format.
#
# ---
# ## Setup
#
# This notebook was tested in Amazon SageMaker Studio on a ml.t3.medium instance with Python 3 (Data Science) kernel.
#
# Let's start by specifying:
# 1. The S3 bucket and prefix that you want to use for training and model data. This should be within the same region as the Notebook Instance, training, and hosting.
# 1. The IAM role arn used to give training and hosting access to your data. See the documentation for how to create these. Note, if more than one role is required for notebook instances, training, and/or hosting, please replace the boto regexp with a the appropriate full IAM role arn string(s).

# %%
# %%time

import os
import boto3
import re
import sagemaker

# Get a SageMaker-compatible role used by this Notebook Instance.
role = sagemaker.get_execution_role()
region = boto3.Session().region_name

### update below values appropriately ###
bucket = sagemaker.Session().default_bucket()
prefix = "sagemaker/DEMO-xgboost-dist-script"
####

print(region)
# Out:
# us-east-1
# CPU times: user 84.1 ms, sys: 2.15 ms, total: 86.3 ms
# Wall time: 185 ms

# %% [markdown]
# ### Fetching the dataset
#
# Following code downloads the data and splits the data into train/validation datasets and upload files to S3.

# %%
from data_utils import load_mnist, upload_to_s3

bucket = sagemaker.Session().default_bucket()
prefix = "DEMO-smdebug-xgboost-mnist"

# %%
# %%time

train_file, validation_file = load_mnist()
upload_to_s3(train_file, bucket, f"{prefix}/train/mnist.train.libsvm")
upload_to_s3(validation_file, bucket, f"{prefix}/validation/mnist.validation.libsvm")
# Out:
# Writing to s3://sagemaker-us-east-1-365792799466/DEMO-smdebug-xgboost-mnist/train/mnist.train.libsvm
# Writing to s3://sagemaker-us-east-1-365792799466/DEMO-smdebug-xgboost-mnist/validation/mnist.validation.libsvm
# CPU times: user 3.74 s, sys: 420 ms, total: 4.16 s
# Wall time: 1min 9s

# %% [markdown]
# ## Training the XGBoost model
#
# After setting training parameters, we kick off training, and poll for status until training is completed, which in this example, takes between few minutes.
#
# To run our training script on SageMaker, we construct a sagemaker.xgboost.estimator.XGBoost estimator, which accepts several constructor arguments:
#
# * __entry_point__: The path to the Python script SageMaker runs for training and prediction.
# * __role__: Role ARN
# * __train_instance_type__ *(optional)*: The type of SageMaker instances for training. __Note__: Because Scikit-learn does not natively support GPU training, Sagemaker Scikit-learn does not currently support training on GPU instance types.
# * __sagemaker_session__ *(optional)*: The session used to train on Sagemaker.
# * __hyperparameters__ *(optional)*: A dictionary passed to the train function as hyperparameters.

# %%
from sagemaker import image_uris

# Below changes the region to be one where this notebook is running
region = boto3.Session().region_name
container = sagemaker.image_uris.retrieve("xgboost", region, "0.90-2")

# %%
from sagemaker import get_execution_role

role = get_execution_role()
base_job_name = "mnist-xgboost-classification"
bucket_path = "s3://{}".format(bucket)

num_round = 250
save_interval = 30
hyperparameters = {
    "max_depth": "5",
    "eta": "0.1",
    "gamma": "4",
    "min_child_weight": "6",
    "silent": "0",
    "objective": "multi:softmax",
    "num_class": "10",  # num_class is required for 'multi:*' objectives
    "num_round": num_round,
}

# %%
from sagemaker.estimator import Estimator

xgboost_algorithm_mode_estimator = Estimator(
    role=role,
    base_job_name=base_job_name,
    instance_count=2,
    instance_type="ml.m5.xlarge",
    image_uri=container,
    hyperparameters=hyperparameters
    
)

# %%
from sagemaker.session import TrainingInput

train_s3_input = TrainingInput(
    "s3://{}/{}/{}".format(bucket, prefix, "train"), content_type="libsvm"
)
validation_s3_input = TrainingInput(
    "s3://{}/{}/{}".format(bucket, prefix, "validation"), content_type="libsvm"
)

# This is a fire and forget event. By setting wait=False, you just submit the job to run in the background.
# Amazon SageMaker will start one training job and release control to next cells in the notebook.
# Follow this notebook to see status of the training job.
xgboost_algorithm_mode_estimator.fit(
    {"train": train_s3_input, "validation": validation_s3_input}, wait=True
)

# %% [markdown]
# ## Train XGBoost Estimator on MNIST data using Spot Instance
#
# Training using spot instance is just adding a simple configuration attribute 'use_spot_instances' to the estimator class.

# %%
# Open Source distributed script mode
from sagemaker.session import Session
from sagemaker.inputs import TrainingInput
from sagemaker.xgboost.estimator import XGBoost

boto_session = boto3.Session(region_name=region)
session = Session(boto_session=boto_session)
script_path = "abalone.py"

xgboost_algorithm_mode_estimator = Estimator(
    role=role,
    base_job_name=base_job_name,
    instance_count=2,
    instance_type="ml.m5.xlarge",
    image_uri=container,
    hyperparameters=hyperparameters,
    use_spot_instances=True,
    max_run=3600,
    max_wait=3600
    
)

train_s3_input = TrainingInput(
    "s3://{}/{}/{}".format(bucket, prefix, "train"), content_type="libsvm"
)
validation_s3_input = TrainingInput(
    "s3://{}/{}/{}".format(bucket, prefix, "validation"), content_type="libsvm"
)

# This is a fire and forget event. By setting wait=False, you just submit the job to run in the background.
# Amazon SageMaker will start one training job and release control to next cells in the notebook.
# Follow this notebook to see status of the training job.

# %%
xgb_script_mode_estimator.fit({"train": train_input, "validation": validation_input})
# Out:
# 2021-08-10 17:37:34 Starting - Starting the training job...ProfilerReport-1628617054: InProgress
# ...
# 2021-08-10 17:38:31 Starting - Launching requested ML instances......
# 2021-08-10 17:39:32 Starting - Preparing the instances for training.........
# 2021-08-10 17:40:53 Downloading - Downloading input data...
# 2021-08-10 17:41:32 Training - Training image download completed. Training in progress..[2021-08-10 17:41:30.020 ip-10-0-141-79.ec2.internal:1 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2021-08-10:17:41:30:INFO] Imported framework sagemaker_xgboost_container.training
# [2021-08-10:17:41:30:INFO] No GPUs detected (normal if no gpus installed)
# [2021-08-10:17:41:30:INFO] Invoking user training script.
# [2021-08-10:17:41:45:INFO] Module abalone does not provide a setup.py.
# Generating setup.py
# [2021-08-10:17:41:45:INFO] Generating setup.cfg
# [2021-08-10:17:41:45:INFO] Generating MANIFEST.in
# [2021-08-10:17:41:45:INFO] Installing module with the following command:
# /miniconda3/bin/python3 -m pip install .
# Processing /opt/ml/code
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Building wheels for collected packages: abalone
#   Building wheel for abalone (setup.py): started
#   Building wheel for abalone (setup.py): finished with status 'done'
#   Created wheel for abalone: filename=abalone-1.0.0-py2.py3-none-any.whl size=5964 sha256=2aa3e5355b4fa34bd9e1ecda5f42895454765b225e08510935d319448725c8ae
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-q25un67i/wheels/3e/0f/51/2f1df833dd0412c1bc2f5ee56baac195b5be563353d111dca6
# Successfully built abalone
# Installing collected packages: abalone
# Successfully installed abalone-1.0.0
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# [2021-08-10:17:41:47:INFO] No GPUs detected (normal if no gpus installed)
# [2021-08-10:17:41:47:INFO] Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_xgboost_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "max_depth": "5",
#         "objective": "reg:squarederror",
#         "eta": "0.2",
#         "num_round": "250",
#         "subsample": "0.7",
#         "gamma": "4",
#         "min_child_weight": "6",
#         "verbosity": "2"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "validation": {
#             "ContentType": "libsvm",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "ContentType": "libsvm",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-xgboost-2021-08-10-17-37-34-345",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-365792799466/sagemaker-xgboost-2021-08-10-17-37-34-345/source/sourcedir.tar.gz",
#     "module_name": "abalone",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "abalone.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"eta":"0.2","gamma":"4","max_depth":"5","min_child_weight":"6","num_round":"250","objective":"reg:squarederror","subsample":"0.7","verbosity":"2"}
# SM_USER_ENTRY_POINT=abalone.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"ContentType":"libsvm","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"ContentType":"libsvm","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=abalone
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_xgboost_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-365792799466/sagemaker-xgboost-2021-08-10-17-37-34-345/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_xgboost_container.training:main","hosts":["algo-1"],"hyperparameters":{"eta":"0.2","gamma":"4","max_depth":"5","min_child_weight":"6","num_round":"250","objective":"reg:squarederror","subsample":"0.7","verbosity":"2"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"ContentType":"libsvm","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"ContentType":"libsvm","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-xgboost-2021-08-10-17-37-34-345","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-365792799466/sagemaker-xgboost-2021-08-10-17-37-34-345/source/sourcedir.tar.gz","module_name":"abalone","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"abalone.py"}
# SM_USER_ARGS=["--eta","0.2","--gamma","4","--max_depth","5","--min_child_weight","6","--num_round","250","--objective","reg:squarederror","--subsample","0.7","--verbosity","2"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MAX_DEPTH=5
# SM_HP_OBJECTIVE=reg:squarederror
# SM_HP_ETA=0.2
# SM_HP_NUM_ROUND=250
# SM_HP_SUBSAMPLE=0.7
# SM_HP_GAMMA=4
# SM_HP_MIN_CHILD_WEIGHT=6
# SM_HP_VERBOSITY=2
# PYTHONPATH=/miniconda3/bin:/:/miniconda3/lib/python/site-packages/xgboost/dmlc-core/tracker:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python3 -m abalone --eta 0.2 --gamma 4 --max_depth 5 --min_child_weight 6 --num_round 250 --objective reg:squarederror --subsample 0.7 --verbosity 2
#
#
# printing training path
# /opt/ml/input/data/train
# train_0.libsvm
# train_1.libsvm
# printing dtrain
# <xgboost.core.DMatrix object at 0x7f6f728e0090>
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=5
# [0]#011train-rmse:8.10755#011validation-rmse:8.12329
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 0 pruned nodes, max_depth=5
# [1]#011train-rmse:6.62577#011validation-rmse:6.64224
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 8 pruned nodes, max_depth=5
# [2]#011train-rmse:5.46091#011validation-rmse:5.48259
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 8 pruned nodes, max_depth=5
# [3]#011train-rmse:4.56473#011validation-rmse:4.59070
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 50 extra nodes, 4 pruned nodes, max_depth=5
# [4]#011train-rmse:3.87422#011validation-rmse:3.91329
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 8 pruned nodes, max_depth=5
# [5]#011train-rmse:3.34983#011validation-rmse:3.38738
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 50 extra nodes, 6 pruned nodes, max_depth=5
# [6]#011train-rmse:2.95381#011validation-rmse:3.00579
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 52 extra nodes, 4 pruned nodes, max_depth=5
# [7]#011train-rmse:2.65431#011validation-rmse:2.72161
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 52 extra nodes, 6 pruned nodes, max_depth=5
# [8]#011train-rmse:2.43113#011validation-rmse:2.51403
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 50 extra nodes, 0 pruned nodes, max_depth=5
# [9]#011train-rmse:2.28349#011validation-rmse:2.37362
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 6 pruned nodes, max_depth=5
# [10]#011train-rmse:2.18351#011validation-rmse:2.27926
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 6 pruned nodes, max_depth=5
# [11]#011train-rmse:2.10809#011validation-rmse:2.21528
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=5
# [12]#011train-rmse:2.04416#011validation-rmse:2.16983
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 4 pruned nodes, max_depth=5
# [13]#011train-rmse:1.99791#011validation-rmse:2.13065
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 52 extra nodes, 0 pruned nodes, max_depth=5
# [14]#011train-rmse:1.95762#011validation-rmse:2.11447
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=5
# [15]#011train-rmse:1.92872#011validation-rmse:2.10066
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 2 pruned nodes, max_depth=5
# [16]#011train-rmse:1.90620#011validation-rmse:2.09050
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=5
# [17]#011train-rmse:1.88623#011validation-rmse:2.09169
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 2 pruned nodes, max_depth=5
# [18]#011train-rmse:1.87076#011validation-rmse:2.08057
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 6 pruned nodes, max_depth=5
# [19]#011train-rmse:1.85303#011validation-rmse:2.08196
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 2 pruned nodes, max_depth=5
# [20]#011train-rmse:1.84337#011validation-rmse:2.07661
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [21]#011train-rmse:1.83842#011validation-rmse:2.07541
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=5
# [22]#011train-rmse:1.82162#011validation-rmse:2.06127
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=5
# [23]#011train-rmse:1.81195#011validation-rmse:2.06799
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=5
# [24]#011train-rmse:1.79867#011validation-rmse:2.06666
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 2 pruned nodes, max_depth=5
# [25]#011train-rmse:1.79486#011validation-rmse:2.06338
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 2 pruned nodes, max_depth=5
# [26]#011train-rmse:1.79149#011validation-rmse:2.06189
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=5
# [27]#011train-rmse:1.78294#011validation-rmse:2.06031
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 4 pruned nodes, max_depth=5
# [28]#011train-rmse:1.78011#011validation-rmse:2.05863
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 0 pruned nodes, max_depth=5
# [29]#011train-rmse:1.77226#011validation-rmse:2.06253
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 56 extra nodes, 2 pruned nodes, max_depth=5
# [30]#011train-rmse:1.75815#011validation-rmse:2.06808
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 0 pruned nodes, max_depth=5
# [31]#011train-rmse:1.74672#011validation-rmse:2.07320
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 2 pruned nodes, max_depth=5
# [32]#011train-rmse:1.74475#011validation-rmse:2.07636
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 2 pruned nodes, max_depth=5
# [33]#011train-rmse:1.73261#011validation-rmse:2.07996
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 2 pruned nodes, max_depth=5
# [34]#011train-rmse:1.72465#011validation-rmse:2.07923
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 4 pruned nodes, max_depth=5
# [35]#011train-rmse:1.71973#011validation-rmse:2.07802
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 2 pruned nodes, max_depth=5
# [36]#011train-rmse:1.71288#011validation-rmse:2.07839
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 0 pruned nodes, max_depth=5
# [37]#011train-rmse:1.70297#011validation-rmse:2.07243
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 4 pruned nodes, max_depth=5
# [38]#011train-rmse:1.69861#011validation-rmse:2.07132
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=5
# [39]#011train-rmse:1.69325#011validation-rmse:2.07655
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 2 pruned nodes, max_depth=5
# [40]#011train-rmse:1.68383#011validation-rmse:2.07813
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 4 pruned nodes, max_depth=5
# [41]#011train-rmse:1.67384#011validation-rmse:2.07329
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 2 pruned nodes, max_depth=5
# [42]#011train-rmse:1.66887#011validation-rmse:2.06849
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=5
# [43]#011train-rmse:1.66454#011validation-rmse:2.06889
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 4 pruned nodes, max_depth=5
# [44]#011train-rmse:1.65999#011validation-rmse:2.07117
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=5
# [45]#011train-rmse:1.65592#011validation-rmse:2.06854
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 40 extra nodes, 2 pruned nodes, max_depth=5
# [46]#011train-rmse:1.64663#011validation-rmse:2.07236
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=5
# [47]#011train-rmse:1.63921#011validation-rmse:2.07270
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=5
# [48]#011train-rmse:1.63495#011validation-rmse:2.07672
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 8 pruned nodes, max_depth=5
# [49]#011train-rmse:1.62961#011validation-rmse:2.07830
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 6 pruned nodes, max_depth=5
# [50]#011train-rmse:1.62432#011validation-rmse:2.08409
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 2 pruned nodes, max_depth=5
# [51]#011train-rmse:1.62012#011validation-rmse:2.08212
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=5
# [52]#011train-rmse:1.61584#011validation-rmse:2.07908
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 2 pruned nodes, max_depth=5
# [53]#011train-rmse:1.61440#011validation-rmse:2.08027
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 2 pruned nodes, max_depth=5
# [54]#011train-rmse:1.60418#011validation-rmse:2.08223
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 2 pruned nodes, max_depth=5
# [55]#011train-rmse:1.59777#011validation-rmse:2.08122
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [56]#011train-rmse:1.59559#011validation-rmse:2.08244
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 4 pruned nodes, max_depth=5
# [57]#011train-rmse:1.58565#011validation-rmse:2.07886
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 6 pruned nodes, max_depth=5
# [58]#011train-rmse:1.57700#011validation-rmse:2.08393
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 6 pruned nodes, max_depth=5
# [59]#011train-rmse:1.57529#011validation-rmse:2.08240
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 4 pruned nodes, max_depth=5
# [60]#011train-rmse:1.56433#011validation-rmse:2.08825
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=5
# [61]#011train-rmse:1.56011#011validation-rmse:2.09130
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 4 pruned nodes, max_depth=5
# [62]#011train-rmse:1.55748#011validation-rmse:2.08902
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 44 extra nodes, 2 pruned nodes, max_depth=5
# [63]#011train-rmse:1.54900#011validation-rmse:2.09199
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 40 extra nodes, 2 pruned nodes, max_depth=5
# [64]#011train-rmse:1.54081#011validation-rmse:2.08932
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 8 pruned nodes, max_depth=5
# [65]#011train-rmse:1.54052#011validation-rmse:2.09084
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 4 pruned nodes, max_depth=5
# [66]#011train-rmse:1.53135#011validation-rmse:2.08825
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=5
# [67]#011train-rmse:1.52730#011validation-rmse:2.09415
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 12 pruned nodes, max_depth=5
# [68]#011train-rmse:1.52541#011validation-rmse:2.09380
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 8 pruned nodes, max_depth=5
# [69]#011train-rmse:1.51824#011validation-rmse:2.09329
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 2 pruned nodes, max_depth=5
# [70]#011train-rmse:1.51382#011validation-rmse:2.08914
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 4 pruned nodes, max_depth=5
# [71]#011train-rmse:1.50575#011validation-rmse:2.09257
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=5
# [72]#011train-rmse:1.50373#011validation-rmse:2.09317
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 6 pruned nodes, max_depth=5
# [73]#011train-rmse:1.50152#011validation-rmse:2.09472
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 2 pruned nodes, max_depth=5
# [74]#011train-rmse:1.49745#011validation-rmse:2.08857
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 6 pruned nodes, max_depth=5
# [75]#011train-rmse:1.49071#011validation-rmse:2.08340
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 12 pruned nodes, max_depth=5
# [76]#011train-rmse:1.48839#011validation-rmse:2.08915
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 8 pruned nodes, max_depth=5
# [77]#011train-rmse:1.48378#011validation-rmse:2.09226
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 6 pruned nodes, max_depth=5
# [78]#011train-rmse:1.47799#011validation-rmse:2.09347
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 4 pruned nodes, max_depth=5
# [79]#011train-rmse:1.46782#011validation-rmse:2.09415
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 2 pruned nodes, max_depth=5
# [80]#011train-rmse:1.46252#011validation-rmse:2.09263
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 8 pruned nodes, max_depth=5
# [81]#011train-rmse:1.46102#011validation-rmse:2.09654
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 4 pruned nodes, max_depth=5
# [82]#011train-rmse:1.45961#011validation-rmse:2.09963
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 2 pruned nodes, max_depth=5
# [83]#011train-rmse:1.45566#011validation-rmse:2.09977
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 4 pruned nodes, max_depth=5
# [84]#011train-rmse:1.44733#011validation-rmse:2.10616
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 50 extra nodes, 6 pruned nodes, max_depth=5
# [85]#011train-rmse:1.43676#011validation-rmse:2.10777
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 8 pruned nodes, max_depth=5
# [86]#011train-rmse:1.43606#011validation-rmse:2.10815
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 8 pruned nodes, max_depth=5
# [87]#011train-rmse:1.42917#011validation-rmse:2.11239
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 0 pruned nodes, max_depth=5
# [88]#011train-rmse:1.42192#011validation-rmse:2.11462
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 16 pruned nodes, max_depth=5
# [89]#011train-rmse:1.41695#011validation-rmse:2.12269
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 10 pruned nodes, max_depth=5
# [90]#011train-rmse:1.41180#011validation-rmse:2.12291
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 6 pruned nodes, max_depth=5
# [91]#011train-rmse:1.40664#011validation-rmse:2.12675
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 8 pruned nodes, max_depth=5
# [92]#011train-rmse:1.40353#011validation-rmse:2.12801
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 10 pruned nodes, max_depth=5
# [93]#011train-rmse:1.40009#011validation-rmse:2.13111
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 4 pruned nodes, max_depth=5
# [94]#011train-rmse:1.39393#011validation-rmse:2.13499
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 4 pruned nodes, max_depth=5
# [95]#011train-rmse:1.39308#011validation-rmse:2.13555
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 6 pruned nodes, max_depth=5
# [96]#011train-rmse:1.39204#011validation-rmse:2.13618
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 2 pruned nodes, max_depth=5
# [97]#011train-rmse:1.38721#011validation-rmse:2.13433
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 4 pruned nodes, max_depth=5
# [98]#011train-rmse:1.38149#011validation-rmse:2.13301
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 8 pruned nodes, max_depth=5
# [99]#011train-rmse:1.37960#011validation-rmse:2.12879
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 2 pruned nodes, max_depth=5
# [100]#011train-rmse:1.37543#011validation-rmse:2.13050
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 8 pruned nodes, max_depth=5
# [101]#011train-rmse:1.37435#011validation-rmse:2.13139
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 2 pruned nodes, max_depth=5
# [102]#011train-rmse:1.36883#011validation-rmse:2.13787
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 8 pruned nodes, max_depth=5
# [103]#011train-rmse:1.36367#011validation-rmse:2.13823
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 16 pruned nodes, max_depth=5
# [104]#011train-rmse:1.36196#011validation-rmse:2.13741
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 2 pruned nodes, max_depth=5
# [105]#011train-rmse:1.35767#011validation-rmse:2.13801
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 24 pruned nodes, max_depth=5
# [106]#011train-rmse:1.35584#011validation-rmse:2.13820
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 10 pruned nodes, max_depth=5
# [107]#011train-rmse:1.35117#011validation-rmse:2.13948
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 8 pruned nodes, max_depth=5
# [108]#011train-rmse:1.34791#011validation-rmse:2.13985
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 12 pruned nodes, max_depth=5
# [109]#011train-rmse:1.34443#011validation-rmse:2.14172
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 12 pruned nodes, max_depth=5
# [110]#011train-rmse:1.34055#011validation-rmse:2.14501
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 16 pruned nodes, max_depth=5
# [111]#011train-rmse:1.33806#011validation-rmse:2.14955
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 12 pruned nodes, max_depth=5
# [112]#011train-rmse:1.33668#011validation-rmse:2.15025
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 4 pruned nodes, max_depth=5
# [113]#011train-rmse:1.33092#011validation-rmse:2.14972
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 4 pruned nodes, max_depth=5
# [114]#011train-rmse:1.32829#011validation-rmse:2.14700
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 50 extra nodes, 4 pruned nodes, max_depth=5
# [115]#011train-rmse:1.31960#011validation-rmse:2.15009
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 4 pruned nodes, max_depth=5
# [116]#011train-rmse:1.31360#011validation-rmse:2.14982
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 20 pruned nodes, max_depth=5
# [117]#011train-rmse:1.30950#011validation-rmse:2.15306
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 12 pruned nodes, max_depth=5
# [118]#011train-rmse:1.30897#011validation-rmse:2.15300
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 4 pruned nodes, max_depth=5
# [119]#011train-rmse:1.30596#011validation-rmse:2.15479
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 2 pruned nodes, max_depth=5
# [120]#011train-rmse:1.30251#011validation-rmse:2.15084
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 8 pruned nodes, max_depth=4
# [121]#011train-rmse:1.29987#011validation-rmse:2.15050
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 2 pruned nodes, max_depth=5
# [122]#011train-rmse:1.29538#011validation-rmse:2.15060
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 2 pruned nodes, max_depth=5
# [123]#011train-rmse:1.28970#011validation-rmse:2.15259
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 8 pruned nodes, max_depth=5
# [124]#011train-rmse:1.28492#011validation-rmse:2.15099
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 12 pruned nodes, max_depth=5
# [125]#011train-rmse:1.28216#011validation-rmse:2.15531
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 10 pruned nodes, max_depth=5
# [126]#011train-rmse:1.27854#011validation-rmse:2.15123
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 2 pruned nodes, max_depth=5
# [127]#011train-rmse:1.27221#011validation-rmse:2.15387
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 10 pruned nodes, max_depth=5
# [128]#011train-rmse:1.26967#011validation-rmse:2.14954
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 10 pruned nodes, max_depth=5
# [129]#011train-rmse:1.26755#011validation-rmse:2.14775
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 46 extra nodes, 2 pruned nodes, max_depth=5
# [130]#011train-rmse:1.26114#011validation-rmse:2.14790
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 8 pruned nodes, max_depth=5
# [131]#011train-rmse:1.25676#011validation-rmse:2.14650
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 22 pruned nodes, max_depth=4
# [132]#011train-rmse:1.25611#011validation-rmse:2.14659
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 10 pruned nodes, max_depth=5
# [133]#011train-rmse:1.25439#011validation-rmse:2.14612
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 4 pruned nodes, max_depth=5
# [134]#011train-rmse:1.25195#011validation-rmse:2.14738
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 10 pruned nodes, max_depth=5
# [135]#011train-rmse:1.24955#011validation-rmse:2.14818
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 10 pruned nodes, max_depth=5
# [136]#011train-rmse:1.24832#011validation-rmse:2.14775
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 44 extra nodes, 12 pruned nodes, max_depth=5
# [137]#011train-rmse:1.24090#011validation-rmse:2.14664
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 8 pruned nodes, max_depth=5
# [138]#011train-rmse:1.23782#011validation-rmse:2.14643
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 6 pruned nodes, max_depth=5
# [139]#011train-rmse:1.23423#011validation-rmse:2.14787
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 8 pruned nodes, max_depth=5
# [140]#011train-rmse:1.23092#011validation-rmse:2.14240
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 12 pruned nodes, max_depth=5
# [141]#011train-rmse:1.22666#011validation-rmse:2.14499
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 44 extra nodes, 4 pruned nodes, max_depth=5
# [142]#011train-rmse:1.21999#011validation-rmse:2.14928
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 18 pruned nodes, max_depth=5
# [143]#011train-rmse:1.21787#011validation-rmse:2.15031
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 12 pruned nodes, max_depth=5
# [144]#011train-rmse:1.21374#011validation-rmse:2.14935
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=5
# [145]#011train-rmse:1.21069#011validation-rmse:2.15101
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 8 pruned nodes, max_depth=5
# [146]#011train-rmse:1.20823#011validation-rmse:2.15040
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 8 pruned nodes, max_depth=5
# [147]#011train-rmse:1.20542#011validation-rmse:2.15097
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 2 pruned nodes, max_depth=5
# [148]#011train-rmse:1.20216#011validation-rmse:2.14961
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 12 pruned nodes, max_depth=5
# [149]#011train-rmse:1.19856#011validation-rmse:2.15082
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 22 pruned nodes, max_depth=5
# [150]#011train-rmse:1.19745#011validation-rmse:2.14962
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 20 pruned nodes, max_depth=5
# [151]#011train-rmse:1.19526#011validation-rmse:2.14975
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 36 extra nodes, 10 pruned nodes, max_depth=5
# [152]#011train-rmse:1.19092#011validation-rmse:2.14906
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 8 pruned nodes, max_depth=5
# [153]#011train-rmse:1.18933#011validation-rmse:2.14865
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 4 pruned nodes, max_depth=5
# [154]#011train-rmse:1.18697#011validation-rmse:2.14952
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 22 pruned nodes, max_depth=4
# [155]#011train-rmse:1.18544#011validation-rmse:2.14824
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 40 extra nodes, 4 pruned nodes, max_depth=5
# [156]#011train-rmse:1.18179#011validation-rmse:2.14749
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 14 pruned nodes, max_depth=5
# [157]#011train-rmse:1.17780#011validation-rmse:2.14504
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 12 pruned nodes, max_depth=5
# [158]#011train-rmse:1.17492#011validation-rmse:2.14428
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 6 pruned nodes, max_depth=5
# [159]#011train-rmse:1.17188#011validation-rmse:2.14507
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 12 pruned nodes, max_depth=5
# [160]#011train-rmse:1.16895#011validation-rmse:2.14629
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 22 pruned nodes, max_depth=5
# [161]#011train-rmse:1.16683#011validation-rmse:2.14743
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 42 extra nodes, 14 pruned nodes, max_depth=5
# [162]#011train-rmse:1.16266#011validation-rmse:2.14612
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 44 extra nodes, 12 pruned nodes, max_depth=5
# [163]#011train-rmse:1.15684#011validation-rmse:2.14575
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 4 pruned nodes, max_depth=5
# [164]#011train-rmse:1.15205#011validation-rmse:2.14232
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 12 pruned nodes, max_depth=5
# [165]#011train-rmse:1.14764#011validation-rmse:2.14416
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 14 pruned nodes, max_depth=5
# [166]#011train-rmse:1.14390#011validation-rmse:2.14549
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 18 pruned nodes, max_depth=5
# [167]#011train-rmse:1.14295#011validation-rmse:2.14829
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 16 pruned nodes, max_depth=5
# [168]#011train-rmse:1.13911#011validation-rmse:2.15178
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 14 pruned nodes, max_depth=5
# [169]#011train-rmse:1.13634#011validation-rmse:2.15832
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 12 pruned nodes, max_depth=5
# [170]#011train-rmse:1.13592#011validation-rmse:2.15859
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 12 pruned nodes, max_depth=5
# [171]#011train-rmse:1.13233#011validation-rmse:2.15947
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 22 pruned nodes, max_depth=5
# [172]#011train-rmse:1.12814#011validation-rmse:2.16038
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 12 pruned nodes, max_depth=5
# [173]#011train-rmse:1.12509#011validation-rmse:2.16324
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 28 pruned nodes, max_depth=5
# [174]#011train-rmse:1.12423#011validation-rmse:2.16357
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 2 pruned nodes, max_depth=5
# [175]#011train-rmse:1.12248#011validation-rmse:2.16250
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 8 pruned nodes, max_depth=4
# [176]#011train-rmse:1.12103#011validation-rmse:2.16308
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 4 pruned nodes, max_depth=5
# [177]#011train-rmse:1.11919#011validation-rmse:2.16313
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 18 pruned nodes, max_depth=5
# [178]#011train-rmse:1.11607#011validation-rmse:2.16395
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 4 pruned nodes, max_depth=5
# [179]#011train-rmse:1.11381#011validation-rmse:2.16286
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 6 pruned nodes, max_depth=5
# [180]#011train-rmse:1.11193#011validation-rmse:2.16148
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 6 pruned nodes, max_depth=5
# [181]#011train-rmse:1.10878#011validation-rmse:2.16267
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 22 pruned nodes, max_depth=5
# [182]#011train-rmse:1.10722#011validation-rmse:2.16078
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 16 pruned nodes, max_depth=5
# [183]#011train-rmse:1.10492#011validation-rmse:2.16180
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 12 pruned nodes, max_depth=4
# [184]#011train-rmse:1.10395#011validation-rmse:2.16219
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 16 pruned nodes, max_depth=4
# [185]#011train-rmse:1.10336#011validation-rmse:2.16322
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 6 pruned nodes, max_depth=5
# [186]#011train-rmse:1.09994#011validation-rmse:2.16501
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 10 pruned nodes, max_depth=5
# [187]#011train-rmse:1.09646#011validation-rmse:2.16658
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 6 pruned nodes, max_depth=5
# [188]#011train-rmse:1.09276#011validation-rmse:2.16568
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 18 pruned nodes, max_depth=5
# [189]#011train-rmse:1.09123#011validation-rmse:2.16359
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 10 pruned nodes, max_depth=5
# [190]#011train-rmse:1.09039#011validation-rmse:2.16452
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 14 pruned nodes, max_depth=5
# [191]#011train-rmse:1.08813#011validation-rmse:2.16538
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 12 pruned nodes, max_depth=5
# [192]#011train-rmse:1.08571#011validation-rmse:2.16466
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 8 pruned nodes, max_depth=5
# [193]#011train-rmse:1.08545#011validation-rmse:2.16491
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 22 pruned nodes, max_depth=5
# [194]#011train-rmse:1.08216#011validation-rmse:2.16518
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 14 pruned nodes, max_depth=5
# [195]#011train-rmse:1.07841#011validation-rmse:2.16571
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 32 extra nodes, 18 pruned nodes, max_depth=5
# [196]#011train-rmse:1.07492#011validation-rmse:2.16654
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 2 pruned nodes, max_depth=5
# [197]#011train-rmse:1.07462#011validation-rmse:2.16599
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 18 pruned nodes, max_depth=5
# [198]#011train-rmse:1.07228#011validation-rmse:2.16606
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 14 pruned nodes, max_depth=5
# [199]#011train-rmse:1.06890#011validation-rmse:2.16418
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 12 pruned nodes, max_depth=5
# [200]#011train-rmse:1.06588#011validation-rmse:2.16628
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 28 pruned nodes, max_depth=5
# [201]#011train-rmse:1.06358#011validation-rmse:2.16533
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 14 pruned nodes, max_depth=5
# [202]#011train-rmse:1.06049#011validation-rmse:2.16602
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 26 pruned nodes, max_depth=5
# [203]#011train-rmse:1.05827#011validation-rmse:2.16804
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 6 pruned nodes, max_depth=5
# [204]#011train-rmse:1.05704#011validation-rmse:2.16940
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 14 pruned nodes, max_depth=5
# [205]#011train-rmse:1.05660#011validation-rmse:2.17010
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 10 pruned nodes, max_depth=5
# [206]#011train-rmse:1.05531#011validation-rmse:2.17007
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 12 pruned nodes, max_depth=4
# [207]#011train-rmse:1.05478#011validation-rmse:2.16922
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 14 pruned nodes, max_depth=5
# [208]#011train-rmse:1.05313#011validation-rmse:2.17074
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 20 pruned nodes, max_depth=0
# [209]#011train-rmse:1.05311#011validation-rmse:2.17074
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 24 extra nodes, 8 pruned nodes, max_depth=5
# [210]#011train-rmse:1.05098#011validation-rmse:2.17174
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 18 pruned nodes, max_depth=5
# [211]#011train-rmse:1.04663#011validation-rmse:2.17502
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 10 pruned nodes, max_depth=4
# [212]#011train-rmse:1.04502#011validation-rmse:2.17462
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 20 pruned nodes, max_depth=0
# [213]#011train-rmse:1.04502#011validation-rmse:2.17462
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 18 pruned nodes, max_depth=0
# [214]#011train-rmse:1.04502#011validation-rmse:2.17462
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 24 pruned nodes, max_depth=5
# [215]#011train-rmse:1.04368#011validation-rmse:2.17352
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 14 pruned nodes, max_depth=5
# [216]#011train-rmse:1.04180#011validation-rmse:2.17226
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 12 pruned nodes, max_depth=5
# [217]#011train-rmse:1.03975#011validation-rmse:2.17430
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 14 pruned nodes, max_depth=5
# [218]#011train-rmse:1.03737#011validation-rmse:2.17532
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 26 extra nodes, 14 pruned nodes, max_depth=5
# [219]#011train-rmse:1.03551#011validation-rmse:2.17492
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 20 extra nodes, 20 pruned nodes, max_depth=5
# [220]#011train-rmse:1.03423#011validation-rmse:2.17650
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 14 pruned nodes, max_depth=5
# [221]#011train-rmse:1.03227#011validation-rmse:2.17685
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 6 pruned nodes, max_depth=5
# [222]#011train-rmse:1.03054#011validation-rmse:2.17813
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 10 pruned nodes, max_depth=5
# [223]#011train-rmse:1.02837#011validation-rmse:2.17495
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 8 pruned nodes, max_depth=5
# [224]#011train-rmse:1.02784#011validation-rmse:2.17547
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 16 pruned nodes, max_depth=5
# [225]#011train-rmse:1.02738#011validation-rmse:2.17439
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 40 extra nodes, 6 pruned nodes, max_depth=5
# [226]#011train-rmse:1.02304#011validation-rmse:2.17401
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 36 pruned nodes, max_depth=5
# [227]#011train-rmse:1.02147#011validation-rmse:2.17378
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 30 pruned nodes, max_depth=0
# [228]#011train-rmse:1.02148#011validation-rmse:2.17379
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 14 extra nodes, 16 pruned nodes, max_depth=5
# [229]#011train-rmse:1.02057#011validation-rmse:2.17571
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 16 pruned nodes, max_depth=5
# [230]#011train-rmse:1.02019#011validation-rmse:2.17707
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 12 pruned nodes, max_depth=5
# [231]#011train-rmse:1.01971#011validation-rmse:2.17692
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 22 extra nodes, 12 pruned nodes, max_depth=5
# [232]#011train-rmse:1.01770#011validation-rmse:2.17363
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 14 pruned nodes, max_depth=0
# [233]#011train-rmse:1.01769#011validation-rmse:2.17363
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 8 pruned nodes, max_depth=5
# [234]#011train-rmse:1.01652#011validation-rmse:2.17491
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 22 pruned nodes, max_depth=4
# [235]#011train-rmse:1.01618#011validation-rmse:2.17429
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 22 pruned nodes, max_depth=5
# [236]#011train-rmse:1.01467#011validation-rmse:2.17449
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 34 extra nodes, 18 pruned nodes, max_depth=5
# [237]#011train-rmse:1.01262#011validation-rmse:2.17724
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 38 extra nodes, 8 pruned nodes, max_depth=5
# [238]#011train-rmse:1.00832#011validation-rmse:2.17507
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 16 pruned nodes, max_depth=4
# [239]#011train-rmse:1.00728#011validation-rmse:2.17385
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 30 extra nodes, 18 pruned nodes, max_depth=5
# [240]#011train-rmse:1.00488#011validation-rmse:2.17237
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 8 pruned nodes, max_depth=5
# [241]#011train-rmse:1.00419#011validation-rmse:2.17277
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 0 extra nodes, 20 pruned nodes, max_depth=0
# [242]#011train-rmse:1.00418#011validation-rmse:2.17277
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 10 extra nodes, 20 pruned nodes, max_depth=5
# [243]#011train-rmse:1.00338#011validation-rmse:2.17685
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 28 extra nodes, 26 pruned nodes, max_depth=5
# [244]#011train-rmse:0.99975#011validation-rmse:2.17961
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 8 extra nodes, 20 pruned nodes, max_depth=4
# [245]#011train-rmse:0.99934#011validation-rmse:2.17970
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 18 extra nodes, 18 pruned nodes, max_depth=5
# [246]#011train-rmse:0.99725#011validation-rmse:2.17754
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 20 pruned nodes, max_depth=5
# [247]#011train-rmse:0.99562#011validation-rmse:2.17851
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 16 extra nodes, 16 pruned nodes, max_depth=5
# [248]#011train-rmse:0.99457#011validation-rmse:2.17774
# [17:41:48] INFO: ../src/tree/updater_prune.cc:101: tree pruning end, 12 extra nodes, 12 pruned nodes, max_depth=5
# [249]#011train-rmse:0.99398#011validation-rmse:2.18023
# 2021-08-10 17:41:54 Uploading - Uploading generated training model
# 2021-08-10 17:42:53 Completed - Training job completed
# ProfilerReport-1628617054: NoIssuesFound
# Training seconds: 104
# Billable seconds: 47
# Managed Spot Training savings: 54.8%
